# %% [markdown]
# # Use sklearn classification methods to predict if a pet will be adopted

# %% [markdown]
# ## Load the packages set

# %%
# import the library
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# sklearn :: utils
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# sklearn :: models
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# sklearn :: evaluation metrics
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import mean_squared_error

sns.set_style('whitegrid')

# %% [markdown]
# # Load the data set

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
print(df_train.shape, df_test.shape)
# Out:
# (10000, 24) (4993, 23)

# %% [markdown]
# # Feature Engineering

# %%
print(df_train.columns)
df_train.head()
# Out:
# Index(['Type', 'Name', 'Age', 'Breed1', 'Breed2', 'Gender', 'Color1', 'Color2',
#        'Color3', 'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed',
#        'Sterilized', 'Health', 'Quantity', 'Fee', 'State', 'RescuerID',
#        'VideoAmt', 'Description', 'PetID', 'PhotoAmt', 'AdoptionSpeed'],
#       dtype='object')
#    Type                                 Name  Age  Breed1  Breed2  Gender  \
# 0     1             â¥â¥â¥ Lily â¥â¥â¥   36     307       0       2
# 1     2                               Cookie    3     266       0       1
# 2     2  Favour Speedy Abundance And Courage    7     250     252       1
# 3     1                                  NaN    3     307       0       1
# 4     2                      Abandoned Kitty    1     266       0       1
#
#    Color1  Color2  Color3  MaturitySize      ...        Health  Quantity  Fee  \
# 0       2       7       0             2      ...             1         1    0
# 1       6       7       0             2      ...             1         1    0
# 2       1       2       0             2      ...             1         4    0
# 3       2       0       0             3      ...             1         1    0
# 4       1       6       7             1      ...             1         1    0
#
#    State                         RescuerID  VideoAmt  \
# 0  41326  337914b09c2fa5460e195197e994ef98         0
# 1  41327  4bb1ebb92158078ad54a6bb23c10dffc         0
# 2  41327  99ba8ce53b4d8515e417e7921563d923         0
# 3  41327  3f3ef74c486beba3bc87f6dbaee772bf         0
# 4  41401  844f03ab8054007d4be6686f3a9702b9         0
#
#                                          Description      PetID PhotoAmt  \
# 0  Adorable 3 year old Lily looking for a forever...  3f8824a3b      1.0
# 1  i rescue this stary kitten from market near my...  9238eb7fc      1.0
# 2  The mother was a Burmese cross and had since p...  f0a1f2b90      2.0
# 3  This puppy is: 1. Male 2. 3 months old 3. Brow...  7d028bdea      4.0
# 4  Mother cat gave birth to a litter of 3 and too...  8377bfe97      0.0
#
#    AdoptionSpeed
# 0              4
# 1              2
# 2              4
# 3              2
# 4              2
#
# [5 rows x 24 columns]

# %%
# Check for missing values
df_train.isnull().sum(axis = 0)
# Out:
# Type               0
# Name             842
# Age                0
# Breed1             0
# Breed2             0
# Gender             0
# Color1             0
# Color2             0
# Color3             0
# MaturitySize       0
# FurLength          0
# Vaccinated         0
# Dewormed           0
# Sterilized         0
# Health             0
# Quantity           0
# Fee                0
# State              0
# RescuerID          0
# VideoAmt           0
# Description        8
# PetID              0
# PhotoAmt           0
# AdoptionSpeed      0
# dtype: int64

# %%
#Lets get rid of 'names' and description as it contains many NaN's and doesnt provide any useful information
df_train.drop(['Name', 'Description'], axis=1)
# Out:
#       Type  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  MaturitySize  \
# 0        1   36     307       0       2       2       7       0             2
# 1        2    3     266       0       1       6       7       0             2
# 2        2    7     250     252       1       1       2       0             2
# 3        1    3     307       0       1       2       0       0             3
# 4        2    1     266       0       1       1       6       7             1
# 5        1    3     218       0       1       3       5       0             2
# 6        1    2     307       0       2       1       7       0             1
# 7        1    8     307       0       2       6       0       0             2
# 8        2    1     243     245       2       1       2       7             1
# 9        1    6     307       0       1       2       7       0             1
# 10       2   12     266       0       3       1       4       7             3
# 11       1   27     307       0       2       3       0       0             2
# 12       1   12     307       0       1       2       0       0             3
# 13       1    2     307       0       1       1       2       7             2
# 14       2    3     266       0       1       3       0       0             2
# 15       2    4     299     299       3       1       0       0             2
# 16       2    2     285       0       2       3       0       0             3
# 17       1   12      72       0       1       2       0       0             2
# 18       2    1     265     265       3       6       0       0             2
# 19       1    2     307       0       1       2       0       0             2
# 20       2    4     266     265       2       1       2       7             2
# 21       2    5     295       0       2       6       7       0             2
# 22       1    2     307       0       2       7       0       0             2
# 23       1   48     128       0       2       2       7       0             1
# 24       2    2     266       0       2       1       5       0             2
# 25       2    2     285     266       3       1       2       7             1
# 26       2    3     266       0       1       2       0       0             2
# 27       1   48     218     205       2       7       0       0             2
# 28       2    2     265       0       2       4       7       0             2
# 29       2    4     266       0       1       1       7       0             3
# ...    ...  ...     ...     ...     ...     ...     ...     ...           ...
# 9970     2    2     266       0       1       1       7       0             2
# 9971     2   12     266       0       2       3       0       0             2
# 9972     2    7     265       0       2       2       7       0             2
# 9973     1   24     307       0       1       3       0       0             2
# 9974     2    1     266     266       3       2       5       7             1
# 9975     2    3     299     265       3       6       0       0             2
# 9976     2    3     265       0       2       3       5       7             2
# 9977     2    2     266       0       2       3       5       6             1
# 9978     2   24     264       0       1       1       7       0             2
# 9979     1    3     307       0       1       1       2       7             1
# 9980     1   15     307       0       1       2       0       0             3
# 9981     1    1     307       0       3       1       7       0             2
# 9982     2    3     265       0       1       6       7       0             2
# 9983     1    5     307       0       1       2       0       0             1
# 9984     2    4     247     292       1       7       0       0             2
# 9985     2    1     266       0       2       4       5       7             2
# 9986     2    2     265       0       3       1       4       7             1
# 9987     2    3     254       0       2       1       2       7             1
# 9988     2    6     265       0       2       2       5       6             2
# 9989     1   12     195       0       1       1       6       7             2
# 9990     1    3     239     307       1       1       2       0             2
# 9991     1    1     307       0       2       1       2       0             2
# 9992     2    2     299       0       1       4       6       0             2
# 9993     2   24     266       0       2       2       3       7             2
# 9994     2    6     285     265       1       6       7       0             2
# 9995     1    1     307       0       2       2       5       7             2
# 9996     1    5     307       0       2       5       0       0             2
# 9997     2    2     265       0       2       3       6       7             2
# 9998     1    1     307       0       1       2       7       0             2
# 9999     2    1     266       0       2       1       2       0             1
#
#       FurLength      ...       Sterilized  Health  Quantity  Fee  State  \
# 0             2      ...                1       1         1    0  41326
# 1             1      ...                2       1         1    0  41327
# 2             1      ...                2       1         4    0  41327
# 3             1      ...                2       1         1    0  41327
# 4             1      ...                2       1         1    0  41401
# 5             1      ...                2       1         1    0  41326
# 6             2      ...                2       1         1    0  41326
# 7             1      ...                1       1         1    0  41336
# 8             1      ...                2       2         1    0  41326
# 9             1      ...                2       1         1    0  41327
# 10            1      ...                1       1         5    0  41401
# 11            1      ...                1       1         1    0  41401
# 12            1      ...                1       1         1    0  41326
# 13            1      ...                2       1         1   20  41327
# 14            1      ...                2       1         1    0  41401
# 15            2      ...                2       1         3    0  41401
# 16            3      ...                2       1         1  750  41326
# 17            2      ...                1       1         1    0  41326
# 18            2      ...                2       1         2    0  41401
# 19            1      ...                2       1         1    0  41326
# 20            2      ...                2       1         1   65  41326
# 21            2      ...                2       1         1    0  41401
# 22            1      ...                2       1         1   20  41327
# 23            1      ...                2       1         1    0  41326
# 24            1      ...                2       1         1    0  41326
# 25            2      ...                2       1         3    0  41326
# 26            1      ...                2       1         1  100  41326
# 27            3      ...                2       1         1    0  41326
# 28            2      ...                2       2         1    0  41326
# 29            1      ...                2       1         2    0  41326
# ...         ...      ...              ...     ...       ...  ...    ...
# 9970          1      ...                2       1         1    0  41326
# 9971          1      ...                1       1         1   50  41401
# 9972          2      ...                2       1         1    0  41326
# 9973          2      ...                2       1         1    0  41401
# 9974          1      ...                2       1         3    0  41326
# 9975          2      ...                2       1         3    0  41326
# 9976          2      ...                2       1         1   50  41401
# 9977          1      ...                2       1         1    0  41401
# 9978          3      ...                2       1         1  200  41326
# 9979          1      ...                2       2         9    0  41326
# 9980          1      ...                2       1         1    0  41326
# 9981          2      ...                2       1         9    0  41326
# 9982          2      ...                2       1         1    0  41326
# 9983          1      ...                2       1         1    0  41326
# 9984          2      ...                2       1         2  100  41326
# 9985          1      ...                2       1         1    0  41326
# 9986          2      ...                2       1         5    0  41326
# 9987          2      ...                2       1         1    0  41326
# 9988          3      ...                2       1         1    0  41336
# 9989          1      ...                1       1         1  200  41326
# 9990          1      ...                2       1         1    0  41326
# 9991          1      ...                2       1         1    0  41326
# 9992          2      ...                2       1         2  100  41401
# 9993          1      ...                1       1         1    0  41326
# 9994          2      ...                2       1         1  200  41326
# 9995          1      ...                2       1         1    0  41326
# 9996          2      ...                1       2         2    0  41330
# 9997          2      ...                2       1         1    0  41401
# 9998          2      ...                2       1         1    0  41326
# 9999          1      ...                2       1         1    0  41326
#
#                              RescuerID  VideoAmt      PetID  PhotoAmt  \
# 0     337914b09c2fa5460e195197e994ef98         0  3f8824a3b       1.0
# 1     4bb1ebb92158078ad54a6bb23c10dffc         0  9238eb7fc       1.0
# 2     99ba8ce53b4d8515e417e7921563d923         0  f0a1f2b90       2.0
# 3     3f3ef74c486beba3bc87f6dbaee772bf         0  7d028bdea       4.0
# 4     844f03ab8054007d4be6686f3a9702b9         0  8377bfe97       0.0
# 5     aa66486163b6cbc25ea62a34b11c9b91         0  965b31ba7       2.0
# 6     d21f689eab9b3faa1b738ecc836b4b36         0  3760c73b1       1.0
# 7     8f955b588a9e571d8e267cd73cdd8a45         0  f41a7de83       2.0
# 8     2587c9957372fc186d3b95cfd12cf322         0  7b660c6af       4.0
# 9     b84a2dd96249074fc4b276e55f608d21         0  f94c2a347       2.0
# 10    b5950e3453c98daba8642f721ce85ba9         0  c5072890c       5.0
# 11    998b9ae6ce5340eac37bfccfee6e3c9a         0  a0e71d03a       4.0
# 12    6345f51519eded0a7b12d4eb31958e18         0  a37c82165       1.0
# 13    7ed6d84e2e6879245e55447aee39c328         0  d0aa84916       1.0
# 14    01f954cdf61526daf3fbeb8a074be742         0  765039f34       6.0
# 15    4fff19129eb51507da75e440270c0b11         0  37ea8d2db      11.0
# 16    c004c5b717affa9822d9ec1ad3eb00fd         0  5b07e0e6a       5.0
# 17    95481e953f8aed9ec3d16fc4509537e8         0  edd2ebd5e       2.0
# 18    22d9e67d412f25866e09f2c098a6ebef         0  2d758a13b       5.0
# 19    4adf17f7d78a2ea23a77ff056b5e7779         0  ee3b21a9a       3.0
# 20    18040c4e8dba340ae2a9eb2c6632a647         0  324266c95       5.0
# 21    47e122a903cad1e2481fa9b84b8db59f         0  1ed55129a       2.0
# 22    7ed6d84e2e6879245e55447aee39c328         0  41b98eea2       1.0
# 23    ec45cf345bf63ed4705049127fda8ac5         0  bf99a973b       0.0
# 24    2fd71579abb6b187630197e7d5b3f1db         0  5de61cf6b       3.0
# 25    b850a575552bc0178aad2b85dbbb318e         0  7addf37de       3.0
# 26    09771cded8c18d94a16a6548377410a8         0  5bae0f028       3.0
# 27    23dd4a93a37a6708c6c69c2879c185ed         0  2533f425e       5.0
# 28    fc7d315a17b33e3b54d09a1afd742ced         0  98f5b7ecf       4.0
# 29    21e79bbc000b68ac3e2514e6f595b85a         0  ec8608c1c       0.0
# ...                                ...       ...        ...       ...
# 9970  ba95caa959cea1a5ebd6a59b3e147f7a         0  b19556858       4.0
# 9971  0b988e2ea168cb196edeba5e297e3bcc         0  07d2a9eff       1.0
# 9972  426b95ac7611d447835ed0dcd9091837         0  96cf0efdb       3.0
# 9973  ee2747ce26468ec44c7194e7d1d9dad9         0  9d4e91ab0       8.0
# 9974  f123745af12d52a752542bd325badda1         0  c18a1acc6       3.0
# 9975  ca58077c7cd1124f91f76ec54937aaea         0  50bbe8e31       7.0
# 9976  98dbf5523142a9c116f51bc7e1cc65a5         0  2127c6e1f       0.0
# 9977  2c711fc92ce10361f5b624d5a9c1e139         0  c458c51c0       3.0
# 9978  aac64f077dc0839603ffaa710dac872c         0  7d2811dc5       1.0
# 9979  c556296168080b6e576647e820903b9d         0  84ce5f32b       9.0
# 9980  b53c009d65a6d34c33233b55b9cfb601         0  dc4e92b83       2.0
# 9981  d1d34c64b5ab9b9f7c086187f96db972         1  09ca98f7b      14.0
# 9982  6407425d7407f5334d8fec7f200e2b2e         0  4e8f0401d       3.0
# 9983  7e3c28c5fdac90b3d4ff3288ac85827e         0  c919eb44b       5.0
# 9984  5eaaa88b5605e700707d363dd1330273         0  5d8568dbd       1.0
# 9985  e62135526c27156b8479420aad166317         0  c5e4cfab0       3.0
# 9986  fac0bde06d5f30f9156e8684edc85d45         0  7baa8082a       5.0
# 9987  5f86038e50ce0def545e64f9a06ab5e2         0  472e86a83       2.0
# 9988  a091196f4e922738eea0a55fa4bb8f7e         0  8415aff49       3.0
# 9989  55031315f7bac6061ec15ddcf928185c         0  bb8795c8d       3.0
# 9990  fa90fa5b1ee11c86938398b60abc32cb         0  b09fa9385       2.0
# 9991  893d9ac780c0203804dc170eee0144cd         0  b32339429       5.0
# 9992  1faf0ae111772205cf2f28b3ecea3276         0  6dbb13673       3.0
# 9993  dd7e4618761fb9c590572a6a95cf8df8         0  9e7aa5866       7.0
# 9994  995cf22984882044311ce85ead68b920         0  9e11a3158       5.0
# 9995  42d5612bc1a78caec3e1342449cb08fd         0  b05d0484f      11.0
# 9996  2fb7d7718f9c7704ab9ae80d95f56597         0  b586e1ea4       3.0
# 9997  5e21416ee557e7470d1113dd98a7e3ae         0  13264f4f4       5.0
# 9998  fa90fa5b1ee11c86938398b60abc32cb         0  3422e4906       7.0
# 9999  d663589ebd522d9bcc362a9ca68e4c26         0  8991aff61       4.0
#
#      AdoptionSpeed
# 0                4
# 1                2
# 2                4
# 3                2
# 4                2
# 5                1
# 6                4
# 7                4
# 8                3
# 9                4
# 10               4
# 11               4
# 12               1
# 13               3
# 14               3
# 15               4
# 16               2
# 17               1
# 18               1
# 19               1
# 20               2
# 21               1
# 22               2
# 23               4
# 24               2
# 25               3
# 26               3
# 27               2
# 28               3
# 29               4
# ...            ...
# 9970             2
# 9971             1
# 9972             4
# 9973             4
# 9974             4
# 9975             2
# 9976             3
# 9977             2
# 9978             1
# 9979             2
# 9980             4
# 9981             3
# 9982             4
# 9983             2
# 9984             2
# 9985             2
# 9986             3
# 9987             4
# 9988             2
# 9989             1
# 9990             3
# 9991             4
# 9992             4
# 9993             1
# 9994             2
# 9995             1
# 9996             4
# 9997             3
# 9998             3
# 9999             3
#
# [10000 rows x 22 columns]

# %%
# apply dummies on the training set
col = 'Health'
df_dummies = pd.get_dummies(df_train[col])
df_dummies.columns = [str(col)+'_'+str(c) for c in df_dummies.columns]
df_train = pd.concat([df_train, df_dummies], axis=1)

# apply the same dummies on the test set
col = 'Health'
df_dummies = pd.get_dummies(df_test[col])
df_dummies.columns = [str(col)+'_'+str(c) for c in df_dummies.columns]
df_test = pd.concat([df_test, df_dummies], axis=1)

# %%
# select the columns
X_columns = ['Age', 'Fee', 'Health_1', 'Health_2', 'Health_3', 'PhotoAmt', 'Quantity', 'Breed1', 'Breed2']
y_column = ['AdoptionSpeed']

# %% [markdown]
# # Model Training

# %%
# split the data using sklearn

threshold = 0.8
X = df_train[X_columns]
y = df_train[y_column]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1.0-threshold, shuffle=True)

print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('y_test', y_test.shape)
# Out:
# X_train (8000, 9)
# y_train (8000, 1)
# X_test (2000, 9)
# y_test (2000, 1)

# %%
# train a random forest classifier 
model = RandomForestClassifier(n_estimators=100, random_state = 80)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# /Users/jacobjablonski/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # Model Evaluation

# %%
kappa = cohen_kappa_score(y_test, y_pred, weights ='quadratic')
print('kappa', round(kappa, 4))
print(confusion_matrix(y_test, y_pred))
# Out:
# kappa 0.2206
# [[  5   9  15   8   9]
#  [  2 111 136  51 107]
#  [  5  75 222  59 132]
#  [  7  78 177 110 115]
#  [  5  52 133  95 282]]

# %%
k = 10
results = []
kf = KFold(n_splits=k)
for train_index, test_index in kf.split(X):
    X_train, X_test = X.values[train_index], X.values[test_index]
    y_train, y_test = y.values[train_index], y.values[test_index]
    model.fit(X_train, y_train.ravel())
    y_pred = model.predict(X_test)
    kappa = cohen_kappa_score(y_test, y_pred, weights ='quadratic')
    results.append(round(kappa, 4))

print('Kappa for each fold:', results)
print('AVG(kappa)', round(np.mean(results), 4))
print('STD(kappa)', round(np.std(results), 4))
# Out:
# Kappa for each fold: [0.2582, 0.2602, 0.2976, 0.2928, 0.2325, 0.2372, 0.2408, 0.3125, 0.2667, 0.2648]
# AVG(kappa) 0.2663
# STD(kappa) 0.0256

# %% [markdown]
# # Prepare for Submission

# %%
df_prediction = df_test[X_columns]
df_test['AdoptionSpeed'] = model.predict(df_prediction)
df_test[['PetID', 'AdoptionSpeed']]
# Out:
#           PetID  AdoptionSpeed
# 0     f42161740              1
# 1     0118db3a8              3
# 2     e5164d828              2
# 3     5335bfb38              1
# 4     ff2cf88a0              4
# 5     1d13441b9              1
# 6     7d835cf7c              2
# 7     577d15fea              4
# 8     91736f444              4
# 9     db194aec8              2
# 10    10516f3c6              2
# 11    c3106dcd5              1
# 12    fc3fbbb99              4
# 13    42dd3f3ff              1
# 14    da3be5cb2              4
# 15    4e9a13862              2
# 16    2fbf2cb7c              3
# 17    f45457bdc              4
# 18    aad08c47b              4
# 19    181d40c5e              4
# 20    1a3c44785              4
# 21    6786609aa              2
# 22    1c67c5f4c              1
# 23    bf6a56d33              2
# 24    06fda20a2              4
# 25    b940cf8b8              2
# 26    239c4b696              2
# 27    b67a29908              2
# 28    72f092b4b              3
# 29    7d1d7a4f6              2
# ...         ...            ...
# 4963  ed0185e39              4
# 4964  bf90589d1              4
# 4965  0f796d3f9              1
# 4966  6d53b2d19              0
# 4967  7bc54baef              1
# 4968  87615b2c6              4
# 4969  6f07e7abf              2
# 4970  3bf6cdab0              2
# 4971  00ac364a4              4
# 4972  578b82f50              3
# 4973  f24991ef7              2
# 4974  2e9a64836              2
# 4975  3dab3050c              4
# 4976  4f6029457              1
# 4977  b23e29c89              3
# 4978  0c46298f8              1
# 4979  2f6cde44b              3
# 4980  2f3677597              4
# 4981  256f40704              4
# 4982  653f94080              1
# 4983  878e36da4              4
# 4984  46cf6356e              2
# 4985  ef50eab33              2
# 4986  a40116bf1              4
# 4987  7ed14130d              3
# 4988  3b2b69d20              2
# 4989  360215e23              4
# 4990  0c612e8df              4
# 4991  9b1241ef0              4
# 4992  ffe7f0b70              1
#
# [4993 rows x 2 columns]

# %%
df_test[['PetID', 'AdoptionSpeed']].to_csv('submission_knn.csv', index=False)
